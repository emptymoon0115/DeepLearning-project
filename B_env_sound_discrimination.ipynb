# %%
import keras
from keras.layers import Activation, Dense, Dropout, Conv2D, \
                         Flatten, MaxPooling2D
from keras.models import Sequential
import librosa
import librosa.display
import numpy as np
import pandas as pd
import random

import warnings
warnings.filterwarnings('ignore')

# %%
# Example of a BELL spectrogram
y, sr = librosa.load('instrument/BELL.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a CELLO spectrogram
y, sr = librosa.load('instrument/Cello.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of EP spectrogram
y, sr = librosa.load('instrument/EP.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a Organ spectrogram
y, sr = librosa.load('instrument/Organ.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a Organ spectrogram
y, sr = librosa.load('instrument/String.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a SYNTH spectrogram
y, sr = librosa.load('instrument/SYNTH.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a Violin spectrogram
y, sr = librosa.load('instrument/Violin.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')
