# %%
import keras
from keras.layers import Activation, Dense, Dropout, Conv2D, \
                         Flatten, MaxPooling2D
from keras.models import Sequential
import librosa
import librosa.display
import numpy as np
import pandas as pd
import random

import warnings
warnings.filterwarnings('ignore')

# %%
# Example of a 808 spectrogram
y, sr = librosa.load('Audio/808.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a bass_A spectrogram
y, sr = librosa.load('Audio/bass_A.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a bass_C spectrogram
y, sr = librosa.load('Audio/bass_C.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a bass_loop spectrogram
y, sr = librosa.load('Audio/bassloop.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a guitar_G spectrogram
y, sr = librosa.load('Audio/guitar_G.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a guitar_lead spectrogram
y, sr = librosa.load('Audio/guitar_lead.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a guitar_song spectrogram
y, sr = librosa.load('Audio/guitar_song.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a high_string spectrogram
y, sr = librosa.load('Audio/high_strings.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a kick spectrogram
y, sr = librosa.load('Audio/kick.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a open_hat spectrogram
y, sr = librosa.load('Audio/open_hat.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a snare spectrogram
y, sr = librosa.load('Audio/snare.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
# Example of a violin spectrogram
y, sr = librosa.load('Audio/violin.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')
